# %%
a="5"
print(type(a))
# Out:
# <class 'str'>

# %%
a="hello world"
print(len(a))
# Out:
# 11

# %%
name=input("enter a number")
print(name)
# Out:
# enter a numbershamil
# shamil

# %%
a="hi hello"
print(a[3])
# Out:
# h

# %%
a="shamil"
print(a[::-1])
# Out:
# limahs

# %%
a="john is asmart boy"
a[1]="o"
print(a)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-14-37a062f45d4b> in <cell line: 2>()
#       1 a="john is asmart boy"
# ----> 2 a[1]="o"
#       3 print(a)
#
# TypeError: 'str' object does not support item assignment

# %%
s="hi how are you"
print(s.lower())
print(s.upper())
print(s.replace("h","z"))
print(s.count("h"))
print(s.index("a"))
print(s.isalpha())
# Out:
# hi how are you
# HI HOW ARE YOU
# zi zow are you
# 2
# 7
# False

# %%
list=["a","b","c"]
print(list)
print(type(list))
# Out:
# ['a', 'b', 'c']
# <class 'list'>

# %%
a="1576"
print(int(a))
# Out:
# 1576

# %%
a=2.87
print(str(a))
# Out:
# 2.87

# %%
a=56
print(float(a))
# Out:
# 56.0

# %%
list1=["hi",20,30]
print(list1[0])
# Out:
# hi

# %%
a=["greeks","for","greek"]
print(a[1])
# Out:
# for

# %%
a[1]="you"
print(a)
# Out:
# ['you', 'you', 'you']

# %%
list1=["apple","orange","banana"]
print(list1[0])
# Out:
# apple

# %%
a=5
b=2
print(a+b)
print(a*b)
print(a%b)
print(a/b)
print(a//b)
# Out:
# 7
# 10
# 1
# 2.5
# 2

# %%
a=5
b=2
print(a>b)
print(a==b)
# Out:
# True
# False

# %%
list1=list(("apple",76,"shamil"))
print(list1)
# Out:
# ['apple', 76, 'shamil']

# %%
thislist=["apple","banana","cherry","orange","kiwi","melon","mango"]
thislist[1:3]=["blackbarry","watermwlon"]
print(thislist[2:5])
print(thislist)
# Out:
# ['watermwlon', 'orange', 'kiwi']
# ['apple', 'blackbarry', 'watermwlon', 'orange', 'kiwi', 'melon', 'mango']

# %%
thislist=["apple","orange","banana"]
thislist.insert(2,"ice")
print(thislist)
# Out:
# ['apple', 'orange', 'ice', 'banana']

# %%
a="nahan"
b="anas"
print(a,b)
# Out:
# nahan anas

# %% [markdown]
# # string (revising)

# %%
a="hello ,world"
print(len(a))
print(type(a))
# Out:
# 12
# <class 'str'>

# %%
a="welcome"
print(a[::2])
# Out:
# wloe

# %%
a="good morning"
print(a[6:11:2])
# Out:
# onn

# %%
#loop through string
for i in "welcome":
  print(i)
# Out:
# w
# e
# l
# c
# o
# m
# e

# %%
for i in range(len("welcome")):
  print(i)
# Out:
# 0
# 1
# 2
# 3
# 4
# 5
# 6

# %%
#(a) check string
a="python is intersting"
print("hello" in a)
# Out:
# False

# %%
#(b)
a="python is interesting"
print("python" in a)
# Out:
# True

# %%
a="python is intersting"
if "interestingq" in a:
 print("yes,found")

# %%
#modifing string
#upper,lower,replace,capitalize,spilt
a="hello, world"
print(a.upper())
print(a.lower())
print(a.capitalize())
print(a.split())
print(a.replace("h","d"))
# Out:
# HELLO, WORLD
# hello, world
# Hello, world
# ['hello,', 'world']
# dello, world

# %%
 #concatente string
a="good"
b="morning"
c=a+b
print(c)
# Out:
# goodmorning

# %%
#f-string
age=50
a="my age is"
print(f"my age is{age}")
# Out:
# my age is50

# %%
#modifier
a=50
print(f"total amount is {a:.3f}")
# Out:
# total amount is 50.000
