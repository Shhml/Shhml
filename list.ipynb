# %%
import random
for _ in range(1,100):
    print(random.randrange(50))
# Out:
# 15
# 27
# 29
# 33
# 44
# 45
# 47
# 29
# 49
# 4
# 8
# 3
# 23
# 15
# 10
# 33
# 5
# 13
# 48
# 39
# 13
# 12
# 33
# 11
# 30
# 7
# 39
# 46
# 18
# 27
# 38
# 8
# 26
# 49
# 28
# 26
# 32
# 21
# 10
# 3
# 34
# 43
# 1
# 5
# 4
# 17
# 16
# 4
# 42
# 15
# 15
# 20
# 27
# 38
# 8
# 32
# 26
# 27
# 4
# 9
# 21
# 18
# 10
# 26
# 19
# 31
# 9
# 17
# 14
# 44
# 20
# 15
# 23
# 8
# 42
# 31
# 11
# 25
# 23
# 5
# 27
# 2
# 48
# 7
# 26
# 27
# 37
# 14
# 17
# 15
# 26
# 34
# 35
# 4
# 28
# 37
# 47
# 3
# 0

# %%
import random
print(random.randrange(1,100))
print(random.randrange(1,50))
# Out:
# 86
# 28

# %%
from random import randint
kaali=[]
for _ in range(25):
   kaali.append(random.randint(1,100))
print(kaali)
# Out:
# [12, 59, 95, 66, 90, 22, 22, 19, 41, 39, 93, 89, 28, 60, 86, 71, 50, 12, 56, 99, 6, 12, 46, 86, 80]

# %%
thislist=["orange","apple","mango","melon"]
thislist.remove("apple")
print(thislist)
# Out:
# ['orange', 'mango', 'melon']

# %%
first=[12,13,14,15]
second=[16,17,18,19]
first.insert(2,100)
newf=first
print("newf=",newf)

second.insert(0,200)
news=second
print("news=",news)
# Out:
# newf= [12, 13, 100, 14, 15]
# news= [200, 16, 17, 18, 19]

# %%
a=[1,2,3,4]
a.remove(1,4)
print(a)

# %%
a="i love you"
print(a.split())
# Out:
# ['i', 'love', 'you']

# %%
a=[1,2,3,4,5]
print(a[3])
# Out:
# 4
